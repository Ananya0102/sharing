# %%
#importing libraries
import matplotlib.pyplot as plt
import pandas
#setting values for x and y
x = [1,2,3,4,5,6]
y = [1,4,9,16,25,36]
plt.plot(x, y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('parabolic function')
plt.show()
